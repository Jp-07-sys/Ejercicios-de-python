# %% [markdown]
# <a href="https://colab.research.google.com/github/Jp-07-sys/Ejercicios-de-python/blob/main/Primera_clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# La ecuacion de la recta es:
# \begin{equation}
# y=mx+b
# \end{equation}
# m es la pendiente y b es la ordenada al origen

# %% [markdown]
# Variables

# %%
x=1
c="hola a todos"
(x,c)
print(x,c)
print(c,x)
# Out:
# 1 hola a todos
# hola a todos 1

# %%
x=4
x="Juan Pablo"
print(x)
# Out:
# Juan Pablo

# %%
a=4 #es una variable de tipo entera
b=3, 10 # variable de punto flotante
c="Buenos dias"
print(a,b,c) #imprimir en pantalla las variables (y el texto)
# Out:
# 4 (3, 10) Buenos dias

# %%
x=str(3)
y=int(3)
z=float(3)
print(type(x),type(y),type(z))
# Out:
# <class 'str'> <class 'int'> <class 'float'>

# %%
print(type(x)), print(type(y)),print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# (None, None, None)

# %%
#Cadenas
a="Juan"
b="Juan"
c="Pablo"
d="González"
print(a,b,c,d)
# Out:
# Juan Juan Pablo González

# %%
x=7
X="Juan Pablo"
print(x,X)
# Out:
# 7 Juan Pablo

# %%
myvar = "Juan"
my_var = "Pablo"
_my_var = "12"
myVar = "2"
MYVAR = "p,q"
myvar2 = "Hola"

# %%
myVariableName="Juan Pablo"
print(myVariableName)
# Out:
# Juan Pablo

# %%
x,y,z,="1","2","3"
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x=y=z="34"
print(x)
print(y)
print(z)
# Out:
# 34
# 34
# 34

# %%
#Calcular el area de un triangulo
# area(a),base(b), altura(h)
b=20 #valor de la base
h=15 #Valor de la altura
a=b*h/2 # fórmula para calcular el área de un triángulo
print("El área del triángulo es",a, "unidades cuadradas") #imprimo resultado
# Out:
# El área del triángulo es 150.0 unidades cuadradas

# %%
Frutas  = ["manzana", "plátano", "piña"]
x, y, z = Frutas
print(x)
print(y)
print(z)
# Out:
# manzana
# plátano
# piña

# %%
resultado= 15/4
print(resultado)
# Out:
# 3.75

# %%
resultado=15//4
print(resultado)
# Out:
# 3

# %%
#suma
resultado=13+19.5
print(resultado)
# Out:
# 32.5

# %%
#resta
resultado=9-15.5
print(resultado)
# Out:
# -6.5

# %%
#mult
resultado=9*15.5
print(resultado)
# Out:
# 139.5

# %%
#division
resultado=17/3
print(resultado)
# Out:
# 5.666666666666667

# %%
#exponcencial
resultado=5**8
print(resultado)
# Out:
# 390625

# %%
#raiz
resultado=25**(1/2)
print(resultado)
# Out:
# 5.0

# %%
#palabras reservadas en python
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#complejos
complejo=2+3j
type(complex)
print(complejo,type(complex))
# Out:
# (2+3j) <class 'type'>

# %%
C=25
#celsius a K
k=(C+273)
#celsius a  F
F=(C*9/5)+32
#Celsius a Rankine
R=(C+273)*9/5
print(k,"Celsius a kelvin")
print(F,"Celsius a Farenheit")
print(R, "Celsius a Rankine")
# Out:
# 298 Celsius a kelvin
# 77.0 Celsius a Farenheit
# 536.4 Celsius a Rankine
