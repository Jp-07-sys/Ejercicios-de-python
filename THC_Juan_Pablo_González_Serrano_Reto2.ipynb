# %% [markdown]
# <a href="https://colab.research.google.com/github/Jp-07-sys/Ejercicios-de-python/blob/main/THC_Juan_Pablo_Gonz%C3%A1lez_Serrano_Reto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.- La secuencia del cortador de pizza perezoso ( The Lazy Caterer's sequence).**
#
# Se trata un problema clásico de combinatoria y geometría que responde a la siguiente pregunta, ¿cuál es el número máximo de piezas en que se puede dividir una pizza utilizando *n* cortes rectos?
# Si tienes una pizza y haces cortes rectos, no necesariamente pasando por el centro y con la posibilidad de cruzarse en cualquier punto, ¿cuál es la mayor cantidad de rebanadas que puedes obtener?. Sabemos que
#
# f(0)=1
#
# f(1)=2
#
# f(2)=4
#
# f(3)=7
#
# Con base en esta información, se puede utilizar la siguiente fórmula de recursión para *n* cortes.
#
# \begin{equation}
# f(n)=f(n−1)+n
# \end{equation}
#
# Genere un programa en Python que muestre la secuencia de n cortes. Proponga un valor apropiado de cortes y justifique porqué escogió dicho valor.

# %%
def cortador_pizza(n):
  f = [1]  # f(0)
  for i in range(1, n + 1):
    f.append(f[i-1] + i)
    return f

# Elegimos un valor de n (puedes cambiarlo)
n = 10
resultado = cortador_pizza(n)

print(f"Secuencia del cortador de pizza perezoso hasta n = {n}:")
print(resultado)
# Out:
# Secuencia del cortador de pizza perezoso hasta n = 10:
# [1, 2]

# %% [markdown]
# Elegí n = 10 cortes porque es un número grande para observar cómo crece la secuencia, pero no tan grande para que sea facil de interpretar los valores. Permite ver claramente el comportamiento y el incremento máximo de piezas por cada corte.

# %% [markdown]
# **2.- Serie de Madhava.**
#
# Utilice un ciclo for para estimar el valor de pi ($\pi$) a partir de los primeros 20 términos de la Serie de Madhava, dada por la siguiente expresión:
#
# \begin{equation}
# \pi \approx \sqrt{12}\left(
# \sum_{k=0}^{19} \frac{(-1)^k}{(2k+1)3^k}
# \right)
# \end{equation}

# %%
import math

# aproximación de pi usando la serie de Madhava con 20 términos
suma = 0

for k in range(20):
    termino = ((-1)**k) / ((2*k + 1) * (3**k))
    suma += termino

pi_aprox = math.sqrt(12) * suma

print("Aproximación de pi usando la Serie de Madhava con 20 términos:")
print(pi_aprox)
# Out:
# Aproximación de pi usando la Serie de Madhava con 20 términos:
# 3.1415926535714034
